# %%
import pandas as pd

df = pd.read_csv("../data/raw/WPP2024_Demographic_Indicators_Medium.csv")
list(df.columns)
# Out:
# /var/folders/gc/2bl359j51qqgvfj_8m6ty1fw0000gn/T/ipykernel_17342/3717148473.py:3: DtypeWarning: Columns (2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/WPP2024_Demographic_Indicators_Medium.csv")
# ['SortOrder',
#  'LocID',
#  'Notes',
#  'ISO3_code',
#  'ISO2_code',
#  'SDMX_code',
#  'LocTypeID',
#  'LocTypeName',
#  'ParentID',
#  'Location',
#  'VarID',
#  'Variant',
#  'Time',
#  'TPopulation1Jan',
#  'TPopulation1July',
#  'TPopulationMale1July',
#  'TPopulationFemale1July',
#  'PopDensity',
#  'PopSexRatio',
#  'MedianAgePop',
#  'NatChange',
#  'NatChangeRT',
#  'PopChange',
#  'PopGrowthRate',
#  'DoublingTime',
#  'Births',
#  'Births1519',
#  'CBR',
#  'TFR',
#  'NRR',
#  'MAC',
#  'SRB',
#  'Deaths',
#  'DeathsMale',
#  'DeathsFemale',
#  'CDR',
#  'LEx',
#  'LExMale',
#  'LExFemale',
#  'LE15',
#  'LE15Male',
#  'LE15Female',
#  'LE65',
#  'LE65Male',
#  'LE65Female',
#  'LE80',
#  'LE80Male',
# ...

# %%
# filtering the data so we have only data from Bangladesh . 
bd = df[df["Location"] == "Bangladesh"].copy()

bd.head()
# Out:
#        SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 56544      144.0     50   NaN       BGD        BD       50.0        4.0
# 56545      144.0     50   NaN       BGD        BD       50.0        4.0
# 56546      144.0     50   NaN       BGD        BD       50.0        4.0
# 56547      144.0     50   NaN       BGD        BD       50.0        4.0
# 56548      144.0     50   NaN       BGD        BD       50.0        4.0
#
#         LocTypeName  ParentID    Location  ...  Q0060Male Q0060Female  \
# 56544  Country/Area    5501.0  Bangladesh  ...   628.5175    636.2870
# 56545  Country/Area    5501.0  Bangladesh  ...   617.8055    628.8580
# 56546  Country/Area    5501.0  Bangladesh  ...   607.5838    621.4841
# 56547  Country/Area    5501.0  Bangladesh  ...   599.4759    615.7679
# 56548  Country/Area    5501.0  Bangladesh  ...   585.0563    604.0998
#
#           Q1550  Q1550Male  Q1550Female     Q1560  Q1560Male  Q1560Female  \
# ...
